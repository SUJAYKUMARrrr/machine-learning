# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
df = pd.read_csv ("D:\\DOWNLOAD\\encoding.csv")

# %%
df
# Out:
#      Name  Gender passed
# 0    aman    male    yes
# 1   priya  female     no
# 2   rahul    male    yes
# 3  anjali  female    yes
# 4    ravi    male     no

# %%
df_label = df.copy()
le = LabelEncoder()
df_label['gender_encoding'] = le.fit_transform(df_label['Gender'])
df_label['passed_encoding'] = le.fit_transform(df_label['passed'])
print("\n label encoding data")
print(df_label[["Name", "Gender", "gender_encoding", "passed", "passed_encoding"]])
# Out:
#  label encoding data
#      Name  Gender  gender_encoding passed  passed_encoding
# 0    aman    male                1    yes                1
# 1   priya  female                0     no                0
# 2   rahul    male                1    yes                1
# 3  anjali  female                0    yes                1
# 4    ravi    male                1     no                0
